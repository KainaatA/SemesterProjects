# %%
print("Enter your choice\n 1. Reverse Pyramid \n 2. Reverse Right angled Triangle\n 3. Hollow Diamond \n 4. Hollow Bisected(Both ways) Diamond\n 5. Star of David\n 6. Hollow Star of David(Top and Bottom)\n")
n = int(input())
run = 0
while run == 0:
        if(n == 1):
            stars=int(input("Enter the numbers of stars for first row"))
            for i in range(stars,0,-1):
                for j in range(0,stars-i):
                    print(end=" ")
                for j in range(0,i):
                    print("*",end=" ")
                print(" ")
            break
        if(n == 2):
            print("Enter the number of stars")
            stars = int(input())
            for i in range(0 , stars , 1):
                for j in range(i , stars , 1):
                    print("*", end="")
                print()     
            break
        if(n == 3):
            stars=int(input("Enter the number of stars"))
            for i in range(n):
                print('  '*(stars-i-1)+'*',end="")
                if i>=1:
                    print('  '*(2*i-1)+' *',end="")
                print('') 
            for i in range(1,stars):
                print('  '*(i)+'*',end="")
                if i!=(stars-1):
                    print('  '*(2*stars-2*i-3)+' *',end="")
                print('')
            break
        if(n == 4):
            
            def printPattern(rows) : 
                k = 0; 
                for i in range(1,rows+1) : 
                    for j in range(1,rows-i+1) : 
                        print(" ",end="")  
                    while (k != (2 * i - 1)) : 
                        if (k == 0 or k == 2 * i - 2 or i==n or k == (2 * i - 2)/2) : 
                            print("*",end="") 
                        else : 
                            print(" ",end="") 
                        k = k + 1             
                    k = 0
                    print(""),       
                rows = rows - 1
                for i in range (rows,0,-1) : 
                    for j in range(0,rows-i+1) : 
                        print(" ",end="") 
                    k = 0
                    while (k != (2 * i - 1)) : 
                        if (k == 0 or k == 2 * i - 2 or k == (2 * i - 2)/2 ) : 
                            print("*",end="") 
                        else : 
                            print(" ",end="") 
                        k = k + 1          
                    print(""), 
            n=int(input("Enter the total number of rows"))
            printPattern(n)             
            break
        if(n == 5):                        
            def printPattern( n) : 
                k = 0
                t=0
                for i in range(1,n+2) : #row 6 
                    if(i==n/2 ):
                        for i in range(1,8) : 
                            for j in range(1,i) : 
                                if(i==n-1):
                                  break
                                if(i==n-2):
                                  print(" ",end="")
                                  break                      
                                print (" ",end="") 

                            for j in range(1,((n+1) * 2 - (2 * i - 1))+1) : 
                                if(i==4):
                                        if(j==3):
                                            print("****",end="")  
                                if (i==1 or j >= 1  or j<=7    ) :                       
                                    if(i==n-1): 
                                        for i in range(0, 2 * n -4) : 
                                            print ('*', end = '') 
                                    print ("*", end="")  
                                else : 
                                    print(" ", end="")  
                            print (""), 
                    for j in range(i,n) : 
                        print(' ', end='') 
                    if(i==4 or i==7):
                        break
                    while (k != (2 * i - 1)) : 
                        if (k == 1 or k==0 or k==2 or k == 2 * i - 2 or k == 2 * (i-1.5) - 2) : 
                            print('*', end='') 
                        else : 
                            print('', end ='') 
                        k = k + 1
                    k = 0; 
                    print ("") 
            n = 6
            printPattern(n) 
            break
        if(n == 6):            
            def printPattern( n) : 
                k = 0
                t=0
                for i in range(1,n+2) : #row 6 
                    if(i==n/2 ):
                        for i in range(1,8) : 
                            for j in range(1,i) : 
                                if(i==n-1):
                                  break
                                if(i==n-2):
                                  print(" ",end="")
                                  break                      
                                print (" ",end="") 
                            for j in range(1,((n+1) * 2 - (2 * i - 1))+1) : 
                                if(i==4):
                                        if(j==3):
                                            print("****",end="") 
                                if (i==1 or j >= 1  or j<=7    ) :
                                    if(i==6): 
                                        if(j==2):
                                            print(" ",end="")
                                        if(j==3):
                                            break
                                    if(i==n-1): 
                                        for i in range(0, 2 * n -4) : 
                                            print ('*', end = '') 
                                    print ("*", end="")  
                                else : 
                                    print(" ", end="")  
                            print (""), 
                    for j in range(i,n) : 
                        print(' ', end='') 
                    if(i==4 or i==7):
                        break
                    while (k != (2 * i - 1)) : 
                        if (k == 0 or  k == 2 * i - 2 or k == 2 * (i-1.5) - 2) : 
                            print(' *', end='') 
                        else : 
                            print('', end ='') 
                        k = k + 1
                    k = 0; 
                    print ("") 
            n = 6
            printPattern(n) 
            break

# %%
# Out:
# 6

# %%
6
